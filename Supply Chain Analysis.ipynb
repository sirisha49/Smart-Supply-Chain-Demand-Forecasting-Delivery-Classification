# %%
import pandas as pd
df= pd.read_excel("DataCoSupplyChainDataset.xlsx")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
data=df[["Type" , "Days for shipping (real)", "Days for shipment (scheduled)", "Delivery Status","Late_delivery_risk","Category Id","Customer Country","Customer Segment","Order Country","Order Status", "Shipping Mode","Order Item Discount", "Order Item Product Price", "Order Item Profit Ratio", "Order Item Quantity", "Order Profit Per Order"]]

# %%
data.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#     Delivery Status  Late_delivery_risk  Category Id Customer Country  \
# 0  Advance shipping                   0           73      Puerto Rico
# 1     Late delivery                   1           73      Puerto Rico
# 2  Shipping on time                   0           73          EE. UU.
# 3  Advance shipping                   0           73          EE. UU.
# 4  Advance shipping                   0           73      Puerto Rico
#
#   Customer Segment Order Country     Order Status   Shipping Mode  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Delivery Status                180519 non-null  object
#  4   Late_delivery_risk             180519 non-null  int64
#  5   Category Id                    180519 non-null  int64
#  6   Customer Country               180519 non-null  object
#  7   Customer Segment               180519 non-null  object
#  8   Order Country                  180519 non-null  object
#  9   Order Status                   180519 non-null  object
#  10  Shipping Mode                  180519 non-null  object
#  11  Order Item Discount            180519 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Customer Country                 0
# Customer Segment                 0
# Order Country                    0
# Order Status                     0
# Shipping Mode                    0
# Order Item Discount              0
# Order Item Product Price         0
# Order Item Profit Ratio          0
# Order Item Quantity              0
# Order Profit Per Order           0
# dtype: int64

# %%
data["Late_delivery_risk"]
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 180514    0
# 180515    1
# 180516    1
# 180517    0
# 180518    0
# Name: Late_delivery_risk, Length: 180519, dtype: int64

# %%
data.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#     Delivery Status  Late_delivery_risk  Category Id Customer Country  \
# 0  Advance shipping                   0           73      Puerto Rico
# 1     Late delivery                   1           73      Puerto Rico
# 2  Shipping on time                   0           73          EE. UU.
# 3  Advance shipping                   0           73          EE. UU.
# 4  Advance shipping                   0           73      Puerto Rico
#
#   Customer Segment Order Country     Order Status   Shipping Mode  \
# ...

# %%
data["Shipping Mode"].value_counts()
# Out:
# Shipping Mode
# Standard Class    107752
# Second Class       35216
# First Class        27814
# Same Day            9737
# Name: count, dtype: int64

# %%
data["Delivery Status"].value_counts()
# Out:
# Delivery Status
# Late delivery        98977
# Advance shipping     41592
# Shipping on time     32196
# Shipping canceled     7754
# Name: count, dtype: int64

# %%
data.dtypes[data.dtypes=='object']
# Out:
# Type                object
# Delivery Status     object
# Customer Country    object
# Customer Segment    object
# Order Country       object
# Order Status        object
# Shipping Mode       object
# dtype: object

# %%
df1=df[["Delivery Status","Customer Country", "Customer Segment","Order Country","Order Status","Shipping Mode"]]

# %%
data.dtypes[data.dtypes!='object']
# Out:
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Late_delivery_risk                 int64
# Category Id                        int64
# Order Item Discount              float64
# Order Item Product Price         float64
# Order Item Profit Ratio          float64
# Order Item Quantity                int64
# Order Profit Per Order           float64
# dtype: object

# %%
df2=df[["Days for shipping (real)","Days for shipment (scheduled)","Late_delivery_risk","Category Id","Order Item Discount","Order Item Product Price","Order Item Profit Ratio","Order Item Quantity","Order Profit Per Order"]]

# %%
pd.DataFrame(data.dtypes) ## printing dtypes of datframe
# Out:
#                                      0
# Type                            object
# Days for shipping (real)         int64
# Days for shipment (scheduled)    int64
# Delivery Status                 object
# Late_delivery_risk               int64
# Category Id                      int64
# Customer Country                object
# Customer Segment                object
# Order Country                   object
# Order Status                    object
# Shipping Mode                   object
# Order Item Discount            float64
# Order Item Product Price       float64
# Order Item Profit Ratio        float64
# Order Item Quantity              int64
# Order Profit Per Order         float64

# %% [markdown]
# ## {'Late delivery': 2, 'Shipping on time':1, 'Advance shipping': 0, 'Shipping canceled':3 })

# %% [markdown]
# ## Train- Test Split

# %%
data['Delivery Status'].unique()
# Out:
# array(['Advance shipping', 'Late delivery', 'Shipping on time',
#        'Shipping canceled'], dtype=object)

# %%
data['Delivery Status'] = data['Delivery Status'] . map({'Late delivery': 2, 'Shipping on time':1, 'Advance shipping': 0,
       'Shipping canceled':3 })

# %%
data.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Delivery Status', 'Late_delivery_risk', 'Category Id',
#        'Customer Country', 'Customer Segment', 'Order Country', 'Order Status',
#        'Shipping Mode', 'Order Item Discount', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity',
#        'Order Profit Per Order'],
#       dtype='object')

# %%
X = data.drop('Delivery Status', axis=1)

# %%
len(X)
# Out:
# 180519

# %%
y = data['Delivery Status']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.25, stratify=y)

# %%
x_train
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 104465   PAYMENT                         4                              2
# 120918  TRANSFER                         5                              4
# 82890      DEBIT                         5                              4
# 69251    PAYMENT                         2                              2
# 74399      DEBIT                         5                              2
# ...          ...                       ...                            ...
# 24858      DEBIT                         2                              1
# 86896   TRANSFER                         6                              4
# 66709      DEBIT                         4                              4
# 54595      DEBIT                         4                              4
# 33912       CASH                         6                              4
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
x_test
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 28616    PAYMENT                         2                              1
# 13334      DEBIT                         2                              4
# 120378  TRANSFER                         4                              4
# 98278      DEBIT                         2                              2
# 68411      DEBIT                         5                              4
# ...          ...                       ...                            ...
# 98024      DEBIT                         3                              2
# 77503   TRANSFER                         2                              1
# 100433  TRANSFER                         3                              4
# 129358     DEBIT                         6                              4
# 64673      DEBIT                         3                              2
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
y_test
# Out:
# 28616     2
# 13334     0
# 120378    1
# 98278     1
# 68411     2
#          ..
# 98024     2
# 77503     3
# 100433    0
# 129358    2
# 64673     2
# Name: Delivery Status, Length: 45130, dtype: int64

# %%
x_train['Category Id'].value_counts()
# Out:
# Category Id
# 17    18504
# 18    16624
# 24    15732
# 46    14436
# 45    13038
# 48    11589
# 43    10295
# 9      9403
# 29     8236
# 37     1529
# 40     1351
# 36     1094
# 26      912
# 13      858
# 35      790
# 41      711
# 75      628
# 63      488
# 3       487
# 76      483
# 7       458
# 62      450
# 33      385
# 74      384
# 66      377
# 68      371
# 72      371
# 67      346
# 65      337
# 71      337
# 44      331
# 12      329
# 64      328
# 32      324
# 59      296
# 38      295
# 69      280
# 5       266
# 73      264
# 6       236
# 11      231
# 30      213
# 61      195
# 60      160
# 70      159
# 31      136
# 2       107
# 10       84
# 16       52
# 34       51
# 4        48
# Name: count, dtype: int64

# %%
x_train = x_train[x_train['Category Id'].isin( [17,18,24,43,46,45,48,29,9])]
x_test = x_test[x_test['Category Id'].isin( [17,18,24,43,46,45,48,29,9])]

# %%
x_train.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Late_delivery_risk', 'Category Id', 'Customer Country',
#        'Customer Segment', 'Order Country', 'Order Status', 'Shipping Mode',
#        'Order Item Discount', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity',
#        'Order Profit Per Order'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))

#subplots
plt.subplot(2,2,1)
sns.histplot(x_train.iloc[:,10], kde=True)
plt.title('Distribution of Order Item Discount')

plt.subplot(2,2,2)
sns.histplot(x_train.iloc[:,11], kde=True)
plt.title('Distribution of Order Item Product Price')

plt.subplot(2,2,3)
sns.histplot(x_train.iloc[:,12], kde=True)
plt.title('Distribution of Order Item Profit Ratio')

plt.subplot(2,2,4)
sns.histplot(x_train.iloc[:,14], kde=True)
plt.title('Distribution of Order Profit Per Order')

#show plots
plt.tight_layout()
plt.show()

# %%
import numpy as np
import warnings
warnings.filterwarnings("ignore")
x_train["log_Order Item Discount"] = np.log(x_train["Order Item Discount"]+1) ## log transformation, log(0) is undefined, So adding +1
x_train["log_Order Item Product Price"] = np.log(x_train["Order Item Product Price"]+1)
x_train["log_Order Item Profit Ratio"] = np.log(x_train["Order Item Profit Ratio"]+1)

warnings.filterwarnings("ignore")
x_test["log_Order Item Discount"] = np.log(x_test["Order Item Discount"]+1) ## log transformation, log(0) is undefined, So adding +1
x_test["log_Order Item Product Price"] = np.log(x_test["Order Item Product Price"]+1)
x_test["log_Order Item Profit Ratio"] = np.log(x_test["Order Item Profit Ratio"]+1)

# %%
x_train.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Late_delivery_risk', 'Category Id', 'Customer Country',
#        'Customer Segment', 'Order Country', 'Order Status', 'Shipping Mode',
#        'Order Item Discount', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity',
#        'Order Profit Per Order', 'log_Order Item Discount',
#        'log_Order Item Product Price', 'log_Order Item Profit Ratio'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))

#subplots
plt.subplot(2,2,1)
sns.histplot(x_train.iloc[:,15], kde=True)
plt.title('Distribution of log Order Item Discount')

plt.subplot(2,2,2)
sns.histplot(x_train.iloc[:,16], kde=True)
plt.title('Distribution of log Order Item Product Price')

plt.subplot(2,2,3)
sns.histplot(x_train.iloc[:,17], kde=True)
plt.title('Distribution of log Order Item Profit Ratio')

plt.subplot(2,2,4)
sns.histplot(x_train.iloc[:,14], kde=True)
plt.title('Distribution of Order Profit Per Order')

#show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Yeo-Johnson Tranformation for Negative Values in Order Item Profit Ratio

# %%
from sklearn.preprocessing import PowerTransformer

pt1= PowerTransformer(method='yeo-johnson')
x_train['powerTrans_Order Item Profit Ratio']=pt1.fit_transform(x_train[['Order Item Profit Ratio']])

# %%
x_test['powerTrans_Order Item Profit Ratio']=pt1.transform(x_test[['Order Item Profit Ratio']])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))


sns.histplot(x_train.iloc[:,18], kde=True)
plt.title('Yeo- Johnson Distribution of Order Item Profit Ratio')


#show plots
plt.tight_layout()
plt.show()

# %%
x_train.drop(['log_Order Item Profit Ratio', 'Order Item Profit Ratio', 'Order Item Product Price', 'Order Item Discount'], axis=1, inplace=True)

# %%
x_test.drop(['log_Order Item Profit Ratio', 'Order Item Profit Ratio', 'Order Item Product Price', 'Order Item Discount'], axis=1, inplace=True)

# %%
x_train = x_train[x_train['Category Id'].isin( [17,18,24,43,46,45,48,29,9])]
x_test = x_test[x_test['Category Id'].isin( [17,18,24,43,46,45,48,29,9])]
y_train = y_train.loc[x_train.index]
y_test = y_test.loc[x_test.index]

# %%
x_train
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 104465   PAYMENT                         4                              2
# 120918  TRANSFER                         5                              4
# 82890      DEBIT                         5                              4
# 69251    PAYMENT                         2                              2
# 74399      DEBIT                         5                              2
# ...          ...                       ...                            ...
# 178037   PAYMENT                         4                              4
# 24858      DEBIT                         2                              1
# 86896   TRANSFER                         6                              4
# 66709      DEBIT                         4                              4
# 54595      DEBIT                         4                              4
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
x_test
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 28616    PAYMENT                         2                              1
# 120378  TRANSFER                         4                              4
# 98278      DEBIT                         2                              2
# 68411      DEBIT                         5                              4
# 68222      DEBIT                         3                              4
# ...          ...                       ...                            ...
# 98024      DEBIT                         3                              2
# 77503   TRANSFER                         2                              1
# 100433  TRANSFER                         3                              4
# 129358     DEBIT                         6                              4
# 64673      DEBIT                         3                              2
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
x_train['Order Country'] = x_train['Order Country'].replace('M�xico', 'Mexico')

# %%
x_train
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 104465   PAYMENT                         4                              2
# 120918  TRANSFER                         5                              4
# 82890      DEBIT                         5                              4
# 69251    PAYMENT                         2                              2
# 74399      DEBIT                         5                              2
# ...          ...                       ...                            ...
# 178037   PAYMENT                         4                              4
# 24858      DEBIT                         2                              1
# 86896   TRANSFER                         6                              4
# 66709      DEBIT                         4                              4
# 54595      DEBIT                         4                              4
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
x_test['Order Country'].value_counts()
# Out:
# Order Country
# Estados Unidos    5655
# M�xico            3002
# Francia           2908
# Alemania          2098
# Brasil            1834
#                   ...
# Chad                 1
# Suazilandia          1
# Surinam              1
# Burkina Faso         1
# But�n                1
# Name: count, Length: 156, dtype: int64

# %%
x_test['Order Country'] = x_test['Order Country'].replace('M�xico', 'Mexico')

# %%
x_test
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 28616    PAYMENT                         2                              1
# 120378  TRANSFER                         4                              4
# 98278      DEBIT                         2                              2
# 68411      DEBIT                         5                              4
# 68222      DEBIT                         3                              4
# ...          ...                       ...                            ...
# 98024      DEBIT                         3                              2
# 77503   TRANSFER                         2                              1
# 100433  TRANSFER                         3                              4
# 129358     DEBIT                         6                              4
# 64673      DEBIT                         3                              2
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
import re

x_train['Order Country'] = x_train['Order Country'].apply(lambda x: re.sub(r'[^\x00-\x7F]+', 'é', x) if isinstance(x, str) else x)

# %%
x_train
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 104465   PAYMENT                         4                              2
# 120918  TRANSFER                         5                              4
# 82890      DEBIT                         5                              4
# 69251    PAYMENT                         2                              2
# 74399      DEBIT                         5                              2
# ...          ...                       ...                            ...
# 178037   PAYMENT                         4                              4
# 24858      DEBIT                         2                              1
# 86896   TRANSFER                         6                              4
# 66709      DEBIT                         4                              4
# 54595      DEBIT                         4                              4
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
x_train = x_train[x_train['Order Country'].isin( ['Estados Unidos','Francia','Mexico','Alemania','Brasil'])]
x_test = x_test[x_test['Order Country'].isin( ['Estados Unidos','Francia','Mexico','Alemania','Brasil'])]
y_train = y_train.loc[x_train.index]
y_test = y_test.loc[x_test.index]

# %%
x_test
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 34312       CASH                         2                              4
# 30844   TRANSFER                         6                              4
# 72424   TRANSFER                         2                              2
# 22774      DEBIT                         6                              4
# 108944   PAYMENT                         4                              4
# ...          ...                       ...                            ...
# 69367    PAYMENT                         4                              2
# 97953      DEBIT                         6                              2
# 98024      DEBIT                         3                              2
# 100433  TRANSFER                         3                              4
# 129358     DEBIT                         6                              4
#
#         Late_delivery_risk  Category Id Customer Country Customer Segment  \
# ...

# %%
x_train['Order Country'] = x_train['Order Country'].replace('Estados Unidos', 'United States')
x_train['Order Country'] = x_train['Order Country'].replace('Francia', 'France')
x_train['Order Country'] = x_train['Order Country'].replace('Brasil', 'Brazil')

# %%
x_test['Order Country'] = x_test['Order Country'].replace('Estados Unidos', 'United States')
x_test['Order Country'] = x_test['Order Country'].replace('Francia', 'France')
x_test['Order Country'] = x_test['Order Country'].replace('Brasil', 'Brazil')

# %%
x_train=pd.get_dummies(x_train, columns=[ 'Type','Customer Country', 'Customer Segment',
       'Order Country', 'Order Status', 'Shipping Mode'], drop_first=True,dtype= int)

# %%
x_test=pd.get_dummies(x_test, columns=[ 'Type','Customer Country', 'Customer Segment',
       'Order Country', 'Order Status', 'Shipping Mode'], drop_first=True,dtype= int)

# %%
x_test
# Out:
#         Days for shipping (real)  Days for shipment (scheduled)  \
# 34312                          2                              4
# 30844                          6                              4
# 72424                          2                              2
# 22774                          6                              4
# 108944                         4                              4
# ...                          ...                            ...
# 69367                          4                              2
# 97953                          6                              2
# 98024                          3                              2
# 100433                         3                              4
# 129358                         6                              4
#
#         Late_delivery_risk  Category Id  Order Item Quantity  \
# 34312                    0           43                    1
# 30844                    1           17                    2
# ...

# %%
x_train.columns
# Out:
# Index(['Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Late_delivery_risk', 'Category Id', 'Order Item Quantity',
#        'Order Profit Per Order', 'log_Order Item Discount',
#        'log_Order Item Product Price', 'powerTrans_Order Item Profit Ratio',
#        'Type_DEBIT', 'Type_PAYMENT', 'Type_TRANSFER',
#        'Customer Country_Puerto Rico', 'Customer Segment_Corporate',
#        'Customer Segment_Home Office', 'Order Country_Brazil',
#        'Order Country_France', 'Order Country_Mexico',
#        'Order Country_United States', 'Order Status_CLOSED',
#        'Order Status_COMPLETE', 'Order Status_ON_HOLD',
#        'Order Status_PAYMENT_REVIEW', 'Order Status_PENDING',
#        'Order Status_PENDING_PAYMENT', 'Order Status_PROCESSING',
#        'Order Status_SUSPECTED_FRAUD', 'Shipping Mode_Same Day',
#        'Shipping Mode_Second Class', 'Shipping Mode_Standard Class'],
#       dtype='object')

# %%
cols = ['Days for shipping (real)', 'Days for shipment (scheduled)', 'Category Id', 'Order Profit Per Order', 'log_Order Item Discount', 'log_Order Item Product Price' , 'powerTrans_Order Item Profit Ratio']

# %%
x_train.columns
# Out:
# Index(['Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Late_delivery_risk', 'Category Id', 'Order Item Quantity',
#        'Order Profit Per Order', 'log_Order Item Discount',
#        'log_Order Item Product Price', 'powerTrans_Order Item Profit Ratio',
#        'Type_DEBIT', 'Type_PAYMENT', 'Type_TRANSFER',
#        'Customer Country_Puerto Rico', 'Customer Segment_Corporate',
#        'Customer Segment_Home Office', 'Order Country_Brazil',
#        'Order Country_France', 'Order Country_Mexico',
#        'Order Country_United States', 'Order Status_CLOSED',
#        'Order Status_COMPLETE', 'Order Status_ON_HOLD',
#        'Order Status_PAYMENT_REVIEW', 'Order Status_PENDING',
#        'Order Status_PENDING_PAYMENT', 'Order Status_PROCESSING',
#        'Order Status_SUSPECTED_FRAUD', 'Shipping Mode_Same Day',
#        'Shipping Mode_Second Class', 'Shipping Mode_Standard Class'],
#       dtype='object')

# %% [markdown]
# ## Feature Scaling

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46165 entries, 104465 to 54595
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Days for shipping (real)            46165 non-null  int64
#  1   Days for shipment (scheduled)       46165 non-null  int64
#  2   Late_delivery_risk                  46165 non-null  int64
#  3   Category Id                         46165 non-null  int64
#  4   Order Item Quantity                 46165 non-null  int64
#  5   Order Profit Per Order              46165 non-null  float64
#  6   log_Order Item Discount             46165 non-null  float64
#  7   log_Order Item Product Price        46165 non-null  float64
#  8   powerTrans_Order Item Profit Ratio  46165 non-null  float64
#  9   Type_DEBIT                          46165 non-null  int32
#  10  Type_PAYMENT                        46165 non-null  int32
# ...

# %%
len(x_train.columns)
# Out:
# 30

# %%
x_train_scale = x_train[cols]
x_train_unscale = x_train.drop(cols,axis = 1)

# %%
x_test_scale = x_test[cols]
x_test_unscale = x_test.drop(cols,axis = 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scale = scaler.fit_transform(x_train_scale)

# %%
x_test_scale.head
# Out:
# <bound method NDFrame.head of         Days for shipping (real)  Days for shipment (scheduled)  Category Id  \
# 34312                          2                              4           43
# 30844                          6                              4           17
# 72424                          2                              2           24
# 22774                          6                              4           17
# 108944                         4                              4           24
# ...                          ...                            ...          ...
# 69367                          4                              2           18
# 97953                          6                              2           17
# 98024                          3                              2           24
# 100433                         3                              4           46
# 129358                         6                              4            9
#
# ...

# %%
x_test_scale = scaler.transform(x_test_scale)

# %%
x_train_scale
# Out:
# array([[ 0.29992744, -0.67677724,  1.14401586, ...,  0.00150153,
#         -0.93257991,  0.80121919],
#        [ 0.91272454,  0.78166231, -0.4556064 , ..., -1.15739164,
#         -0.93206981, -0.71127806],
#        [ 0.91272454,  0.78166231,  0.92588555, ..., -0.0326431 ,
#          1.37650782,  1.42919295],
#        ...,
#        [ 0.29992744,  0.78166231,  1.14401586, ...,  0.00150153,
#         -0.93257991,  0.6151548 ],
#        [ 0.29992744,  0.78166231, -0.89186702, ...,  0.03440425,
#          0.29463608,  0.73795849],
#        [ 0.29992744,  0.78166231,  1.28943607, ...,  0.55898068,
#          0.85140196,  1.42919295]])

# %%
x_train_scale = pd.DataFrame(x_train_scale, columns = cols)

# %%
x_train_scale
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  Category Id  \
# 0                      0.299927                      -0.676777     1.144016
# 1                      0.912725                       0.781662    -0.455606
# 2                      0.912725                       0.781662     0.925886
# 3                     -0.312870                       0.781662    -0.092056
# 4                     -0.925667                      -1.405997    -0.455606
# ...                         ...                            ...          ...
# 46160                 -0.925667                      -1.405997    -0.964577
# 46161                 -0.925667                       0.781662    -0.964577
# 46162                  0.299927                       0.781662     1.144016
# 46163                  0.299927                       0.781662    -0.891867
# 46164                  0.299927                       0.781662     1.289436
#
# ...

# %%
x_test_scale = pd.DataFrame(x_test_scale, columns = cols)

# %%
x_train = pd.concat([x_train_unscale.reset_index(drop= True), x_train_scale], axis = 1)

# %%
x_train
# Out:
#        Late_delivery_risk  Order Item Quantity  Type_DEBIT  Type_PAYMENT  \
# 0                       1                    5           0             1
# 1                       1                    1           0             0
# 2                       1                    1           1             0
# 3                       0                    3           0             0
# 4                       1                    3           0             1
# ...                   ...                  ...         ...           ...
# 46160                   1                    5           0             0
# 46161                   0                    1           0             0
# 46162                   0                    1           0             1
# 46163                   0                    1           1             0
# 46164                   0                    1           1             0
#
#        Type_TRANSFER  Customer Country_Puerto Rico  \
# ...

# %%
x_test = pd.concat([x_test_unscale.reset_index(drop= True), x_test_scale], axis = 1)

# %%
x_test
# Out:
#        Late_delivery_risk  Order Item Quantity  Type_DEBIT  Type_PAYMENT  \
# 0                       0                    1           0             0
# 1                       1                    2           0             0
# 2                       0                    2           0             0
# 3                       1                    3           1             0
# 4                       0                    4           0             1
# ...                   ...                  ...         ...           ...
# 15492                   1                    1           0             1
# 15493                   1                    2           1             0
# 15494                   1                    2           1             0
# 15495                   0                    1           0             0
# 15496                   1                    3           1             0
#
#        Type_TRANSFER  Customer Country_Puerto Rico  \
# ...

# %%
y_train.value_counts()
# Out:
# Delivery Status
# 2    25441
# 0    10452
# 1     8174
# 3     2098
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# Delivery Status
# 2    8567
# 0    3501
# 1    2736
# 3     693
# Name: count, dtype: int64

# %%
len(x_train)
# Out:
# 46165

# %%
len(x_test)
# Out:
# 15497

# %%
len(y_train)
# Out:
# 46165

# %%
len(y_test)
# Out:
# 15497

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
import numpy as np

models = {
    "SVM": (SVC(), {
        "C": [0.1, 0.001, 1, 10],
        "kernel": ["linear", "rbf", "poly"],
        "gamma": ["scale", "auto", 0.01, 0.1, 0.001],
        "degree": [2, 3, 4, 7, 9],  # For polynomial kernel
    }),
    "KNeighbors": (KNeighborsClassifier(), {
        "n_neighbors": [2, 3, 5, 7, 9],
        "weights": ["uniform", "distance"],
        "metric": ["euclidean", "manhattan", "minkowski"],
        "p": [1, 2],  # Manhattan (p=1), Euclidean (p=2)
    }),
    "NaiveBayes": (GaussianNB(), {
        "var_smoothing": np.logspace(0, -9, num=10),  # Explore smoothing parameters
    }),
    "XGBoost": (XGBClassifier(use_label_encoder=False, eval_metric='mlogloss'), {
        "n_estimators": [50, 100, 150],
        "learning_rate": [0.01, 0.1, 0.2],
        "max_depth": [3, 5, 7],
        "subsample": [0.8, 0.6],
        "colsample_bytree": [0.8, 0.6],
    }),
    "AdaBoost": (AdaBoostClassifier(), {
        "n_estimators": [50, 100, 150],
        "learning_rate": [0.01, 0.1, 1],
        "algorithm": ['SAMME', 'SAMME.R']
    })
}

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

best_model = None
best_test_score = 0
best_name = ""

for name, (model, param_grid) in models.items():
    print(f"Optimizing {name}...")
    # Use RandomizedSearchCV for hyperparameter optimization
    random_search = RandomizedSearchCV(model, param_grid, n_iter=10,  # You can adjust n_iter to your needs
                                       scoring='accuracy', cv=5, random_state=42, verbose=3)
    random_search.fit(x_train, y_train)

    # Evaluate the model on the test set
    test_score = random_search.best_estimator_.score(x_test, y_test)  # Testing accuracy

    print(f"Best parameters for {name}: {random_search.best_params_}")
    print(f"CV accuracy for {name}: {random_search.best_score_}")
    print(f"Test accuracy for {name}: {test_score}\n")

    # Track the model with the best test accuracy
    if test_score > best_test_score and test_score < 0.98:
        best_test_score = test_score
        best_model = random_search.best_estimator_
        best_name = name

# Summary of the best model
print(f"The best model is {best_name} with a test accuracy of {best_test_score}.")
# Out:
# Optimizing SVM...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END C=1, degree=7, gamma=0.01, kernel=poly;, score=0.552 total time= 2.0min
# [CV 2/5] END C=1, degree=7, gamma=0.01, kernel=poly;, score=0.551 total time= 2.1min
# [CV 3/5] END C=1, degree=7, gamma=0.01, kernel=poly;, score=0.552 total time= 2.5min
# [CV 4/5] END C=1, degree=7, gamma=0.01, kernel=poly;, score=0.551 total time= 2.4min
# [CV 5/5] END C=1, degree=7, gamma=0.01, kernel=poly;, score=0.551 total time= 1.8min
# [CV 1/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=1.000 total time=   4.8s
# [CV 2/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=1.000 total time=   4.5s
# [CV 3/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=1.000 total time=   4.0s
# [CV 4/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=1.000 total time=   4.1s
# [CV 5/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=1.000 total time=   4.0s
# ...

# %%
# Final report on the best model
print(f"Best Model: {best_name}")
print(f"Best Test Set Accuracy: {best_test_score}")
y_pred = best_model.predict(x_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Best Model: KNeighbors
# Best Test Set Accuracy: 0.974124024004646
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      3501
#            1       0.97      0.90      0.93      2736
#            2       1.00      1.00      1.00      8567
#            3       0.99      0.86      0.92       693
#
#     accuracy                           0.97     15497
#    macro avg       0.97      0.94      0.95     15497
# weighted avg       0.97      0.97      0.97     15497

# %% [markdown]
# ## Regression

# %%
x= data1.drop('Order Item Quantity', axis=1)
y= data1['Order Item Quantity']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 45)

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet

models = {
    "RandomForestRegressor": (RandomForestRegressor(), {
        "n_estimators": [50, 100, 200, 300],
        "max_depth": [None, 10, 20, 30, 40],
        "min_samples_split": [2, 4, 6, 8],
        "min_samples_leaf": [1, 2, 3],
        "bootstrap": [True, False],
    }),
    "SVR": (SVR(), {
        "C": [0.1, 1, 10, 100],
        "kernel": ["linear", "rbf", "poly"],
        "gamma": ["scale", "auto", 0.01, 0.1, 0.001],
        "degree": [2, 3, 4, 5],  # For polynomial kernel
    }),
    "KNeighborsRegressor": (KNeighborsRegressor(), {
        "n_neighbors": [3, 5, 7, 10],
        "weights": ["uniform", "distance"],
        "metric": ["euclidean", "manhattan"],
    }),
    "LinearRegression": (LinearRegression(), {
        # Linear Regression usually doesn't have hyperparameters for grid search,
        # but you might choose to add parameters related to data preprocessing steps here
    }),
    "Lasso": (Lasso(), {
        "alpha": [0.001, 0.01, 0.1, 1, 10],
        "selection": ["cyclic", "random"],
    }),
    "Ridge": (Ridge(), {
        "alpha": [0.1, 1, 10, 100, 1000],
    }),
    "ElasticNet": (ElasticNet(), {
        "alpha": [0.1, 1, 10, 100],
        "l1_ratio": [0.1, 0.5, 0.9],  # Ratio between l1 and l2 regularization
    })
}

# %%
best_model = None
best_test_score = -float('inf')  # Initialize with the lowest possible score
best_name = ""

for name, (model, param_grid) in models.items():
    print(f"Optimizing {name}...")
    # Use GridSearchCV for hyperparameter optimization
    grid = GridSearchCV(model, param_grid, scoring='r2', cv=5)  # Use R^2 score for scoring
    grid.fit(x_train, y_train)

    # Evaluate the model on the test set
    test_score = grid.best_estimator_.score(x_test, y_test)  # R^2 score for the test set

    print(f"Best parameters for {name}: {grid.best_params_}")
    print(f"CV R^2 score for {name}: {grid.best_score_}")
    print(f"Test R^2 score for {name}: {test_score}\n")

    # Track the model with the highest R^2 score
    if test_score > best_test_score:
        best_test_score = test_score
        best_model = grid.best_estimator_
        best_name = name

# At the end, you can summarize or use the best model as needed
print(f"The best model is {best_name} with an R^2 score of {best_test_score} on the test set.")
